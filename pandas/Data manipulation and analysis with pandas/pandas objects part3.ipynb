# %% [markdown]
# **DataFrame and Series common functionality**

# %%
import pandas as pd

# %%
ser = pd.Series(list('abcedfgh'))
df = pd.read_csv('employee_attrition.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4861/226666403.py in <cell line: 0>()
#       1 ser = pd.Series(list('abcedfgh'))
# ----> 2 df = pd.read_csv('employee_attrition.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
ser.head()
# Out:
# 0    a
# 1    b
# 2    c
# 3    e
# 4    d
# dtype: object

# %%
df.tail(3)
# Out:
#       Age Attrition     BusinessTravel  DailyRate  DistanceFromHome  \
# 1467   27        No      Travel_Rarely        155                 4
# 1468   49        No  Travel_Frequently       1023                 2
# 1469   34        No      Travel_Rarely        628                 8
#
#       EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 1467                        2   Male          87               4         2
# 1468                        4   Male          63               2         2
# 1469                        2   Male          82               4         2
#
#       ...  PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# 1467  ...                  4                        2                 1
# 1468  ...                  3                        4                 0
# 1469  ...                  3                        1                 0
#
#       TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# ...

# %%
print(ser[2:5])
# Out:
# 2    c
# 3    e
# 4    d
# dtype: object

# %%
age = df['Age']
print(type(age))
age
# Out:
# <class 'pandas.core.series.Series'>
# 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64

# %%
rows = df[2:6]
print(type(rows))

rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Age Attrition     BusinessTravel  DailyRate  DistanceFromHome  \
# 2   37       Yes      Travel_Rarely       1373                 2
# 3   33        No  Travel_Frequently       1392                 3
# 4   27        No      Travel_Rarely        591                 2
# 5   32        No  Travel_Frequently       1005                 2
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  ...  \
# 2                        4    Male          92               2         1  ...
# 3                        4  Female          56               3         1  ...
# 4                        1    Male          40               3         1  ...
# 5                        4    Male          79               3         1  ...
#
#    PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# 2                  3                        2                 0
# 3                  3                        3                 0
# ...

# %% [markdown]
# **Shape (Decides dimension - Gives rows and columns count)**

# %%
ser.shape
# Out:
# (8,)

# %%
df.shape
# Out:
# (1470, 26)

# %% [markdown]
# **describe() - Verbose**

# %%
ser.describe()
# Out:
# count     8
# unique    8
# top       a
# freq      1
# dtype: object

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome  EnvironmentSatisfaction  \
# count  1470.000000  1470.000000       1470.000000              1470.000000
# mean     36.923810   802.485714          9.192517                 2.721769
# std       9.135373   403.509100          8.106864                 1.093082
# min      18.000000   102.000000          1.000000                 1.000000
# 25%      30.000000   465.000000          2.000000                 2.000000
# 50%      36.000000   802.000000          7.000000                 3.000000
# 75%      43.000000  1157.000000         14.000000                 4.000000
# max      60.000000  1499.000000         29.000000                 4.000000
#
#         HourlyRate  JobInvolvement     JobLevel  JobSatisfaction  \
# count  1470.000000     1470.000000  1470.000000      1470.000000
# mean     65.891156        2.729932     2.063946         2.728571
# std      20.329428        0.711561     1.106940         1.102846
# ...
