# %%
import random

airlines = ["Delta", "United", "Southwest", "American", "JetBlue"]

random.seed(42)
selected_airline = random.sample(airlines,k=4)
selected_airline
# Out:
# ['Delta', 'JetBlue', 'Southwest', 'United']

# %%
import pandas as pd

flight_data = pd.read_csv("airlines_flights_data.csv")
flight_data.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
flight_10 = flight_data.sample(n=10, random_state=42)
flight_10
# Out:
#          index    airline     flight source_city departure_time stops  \
# 27131    27131  Air_India     AI-506       Delhi        Morning   one
# 266857  266857    Vistara     UK-706     Kolkata        Morning   one
# 141228  141228    Vistara     UK-772     Kolkata        Morning   one
# 288329  288329    Vistara     UK-824     Chennai          Night   one
# 97334    97334  Air_India     AI-501   Bangalore      Afternoon   one
# 135931  135931    AirAsia     I5-510     Kolkata  Early_Morning   one
# 290630  290630    Vistara     UK-826     Chennai      Afternoon  zero
# 141944  141944     Indigo  6.00E-271     Kolkata  Early_Morning   one
# 244517  244517  Air_India     AI-619      Mumbai          Night   one
# 215903  215903    Vistara     UK-953       Delhi          Night   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 27131   Early_Morning          Kolkata   Economy     19.75         40   7366
# ...
