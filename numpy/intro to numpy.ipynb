# %%
import numpy as np

# %%
List_1=[10,20,30,40]
List_1
# Out:
# [10, 20, 30, 40]

# %%
type(List_1)
# Out:
# list

# %%
Tuple_1 = (10,20,30,40)

# %%
type(Tuple_1)
# Out:
# tuple

# %%
Tuple_1[1]=50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5298/981051095.py in <cell line: 0>()
# ----> 1 Tuple_1[1]=50
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# convert list to array entity

# %%
arr = np.array(List_1)

# %%
arr
# Out:
# array([10, 20, 30, 40])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr[2]
# Out:
# np.int64(30)

# %%
arr[1:3]
# Out:
# array([20, 30])

# %%
#Arrange
np.arange(10,80,5)
# Out:
# array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75])

# %%
np.linspace(10,80,5)
# Out:
# array([10. , 27.5, 45. , 62.5, 80. ])

# %%
np.random.randint(20,100,15)
# Out:
# array([34, 98, 37, 27, 45, 49, 47, 37, 27, 24, 92, 41, 73, 64, 48])

# %%
arr_rand=np.random.randint(20,100,16)
arr_rand
# Out:
# array([84, 97, 91, 68, 98, 65, 61, 60, 94, 87, 28, 64, 59, 99, 67, 79])

# %%
arr_rand_2d= arr_rand.reshape(4,4)
arr_rand_2d
# Out:
# array([[84, 97, 91, 68],
#        [98, 65, 61, 60],
#        [94, 87, 28, 64],
#        [59, 99, 67, 79]])

# %%
arr_rand_2d[0:3,2:]
# Out:
# array([[91, 68],
#        [61, 60],
#        [28, 64]])

# %% [markdown]
# Conditional operations

# %%
arr1=np.random.randint(20,500,16)
arr1
# Out:
# array([186, 103, 390, 355, 409,  41, 476, 298, 322, 343,  55, 221, 424,
#        308, 323, 245])

# %%
arr1[(arr1<100) & (arr1>50)]
# Out:
# array([55])

# %%
arrA= np.array([22,33,44,55])
arrB= np.array([25,35,45,60])

# %%
arrA*arrB
# Out:
# array([ 550, 1155, 1980, 3300])

# %%
np.sqrt(arrA)
# Out:
# array([4.69041576, 5.74456265, 6.63324958, 7.41619849])

# %%
np.sin(arrA)
# Out:
# array([-0.00885131,  0.99991186,  0.01770193, -0.99975517])

# %%
np.max(arrA)
# Out:
# np.int64(55)

# %%
np.min(arrA)
# Out:
# np.int64(22)

# %%
np.argmin(arrA)
# Out:
# np.int64(0)

# %%
np.argmax(arrA)
# Out:
# np.int64(3)
